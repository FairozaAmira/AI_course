# %% [markdown]
# # Solution for Matplotlib Exercises

# %% [markdown]
# **Question 1**
#
# Create a cosine values of data that range from 0 to 10 by using numpy.
# Use `np.linspace()` to get the range value from 0 to 10. Use `np.cos()` to get the cosine values for the value above. Then use `plt.plot()` to plot the line graph for the cosine values above.

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import numpy as np

fig = plt.figure(1)
x = np.linspace(0,10)
y = np.cos(x)
plt.plot(x,y)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# **Question 2**
#
# Create an empty figure by using `plt.figure()`. Then, create the subfigures of the figure by using `plt.subplots()`.

# %%
fig, ax_lst = plt.subplots(2, 2)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# **Question 3**
#
# By referring to this page,
#
# https://matplotlib.org/3.1.0/tutorials/introductory/pyplot.html#sphx-glr-tutorials-introductory-pyplot-py
#
# Try to plot different types of graph.

# %%
t = np.arange(0., 5., 0.1)

fig = plt.figure(3)
fig = plt.plot(t, t, 'r--', t, t**2, 'bs', t, t**3, 'g^')
plt.show(fig)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# **Question 4**
#
# Refer to this page, https://matplotlib.org/3.1.0/tutorials/introductory/images.html#sphx-glr-tutorials-introductory-images-py, download any image and save in the same folder of this notebook, read and create histogram for this image.

# %%
import matplotlib.image as mpimg

img = mpimg.imread("me.jpg")
print(img)
# Out:
# [[[155 156 160]
#   [141 142 146]
#   [122 123 127]
#   ...
#   [151 150 122]
#   [ 79  78  50]
#   [ 64  63  35]]
#
#  [[173 174 178]
#   [152 153 157]
#   [137 138 142]
#   ...
#   [ 96  95  67]
#   [107 106  78]
#   [146 145 117]]
#
#  [[164 165 169]
#   [140 141 145]
#   [130 131 135]
#   ...
#   [166 164 139]
#   [169 167 142]
#   [130 128 103]]
#
#  ...
#
#  [[ 60  61  53]
#   [ 60  61  53]
#   [ 59  60  52]
#   ...
#   [ 49  54  57]
#   [ 53  58  61]
#   [ 46  51  54]]
#
#  [[ 68  69  61]
#   [ 68  68  60]
#   [ 66  66  58]
#   ...
#   [ 58  64  64]
#   [ 50  56  56]
#   [ 48  54  54]]
#
#  [[ 63  63  55]
#   [ 62  62  54]
#   [ 59  59  51]
#   ...
#   [ 59  65  65]
#   [ 64  70  70]
#   [ 48  54  54]]]

# %%
fig = plt.figure(4)
plt.imshow(img)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig = plt.figure(5)
plt.hist(img[:,:,1].ravel())
# Out:
# <img src="data:image/png;base64,..." width="640">
# (array([  4067.,  79079., 148931., 110094.,  76616.,  81657.,  90280.,
#          55759.,  26610.,  18107.]),
#  array([  0. ,  25.5,  51. ,  76.5, 102. , 127.5, 153. , 178.5, 204. ,
#         229.5, 255. ]),
#  <a list of 10 Patch objects>)
