# %%
# assign 2 to the variable of 'x'
x = 2
print(x)
# Out:
# 2

# %%
x = 1       # x is an integer
print(x)
x = 'hello'  # x is a string
print(x)
x = [1,2,3]  # x is a list
print(x)
# Out:
# 1
# hello
# [1, 2, 3]

# %%
y = x
print(y)
# Out:
# [1, 2, 3]

# %%
x.append(4) #append 4 to the list of x
print(y)
# Out:
# [1, 2, 3, 4]

# %%
x = 'something else'
print(y)
# Out:
# [1, 2, 3, 4]
